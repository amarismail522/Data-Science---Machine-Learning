# %% [markdown]
# The sinking of the Titanic is one of the most infamous shipwrecks in history. On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew.
#
# It took about $7.5 million to build the Titanic and it sunk under the ocean due to collision.

# %% [markdown]
# ![titanic/info.png](titanic/info.png)

# %% [markdown]
# # Variable Notes
#
# **pclass:** A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# **age:** Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# **sibsp:** The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# **parch:** The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# # Part1: EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("fivethirtyeight")
import warnings
warnings.filterwarnings("ignore")
# %matploblib inline
# Out:
# UsageError: Line magic function `%matploblib` not found.

# %%
data = pd.read_csv("titanic/train.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()/len(data)*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
data["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# How many Survived?

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data["Survived"].value_counts().plot.pie(explode=[0,0.1],autopct="%1.1f%%",ax=ax[0],shadow=True)
ax[0].set_title("Survived")
ax[0].set_ylabel('')
sns.countplot(x=data["Survived"],ax=ax[1])
ax[1].set_title("Survived")
plt.show()

# %% [markdown]
# It is evident that not many passengers survived the accident.
#
# Out of 891 passengers in training set, only around 350 survived i.e Only **38.4%** of the total training set survived the crash. We need to dig down more to get better insights from the data and see which categories of the passengers did survive and who didn't.
#
# We will try to check the survival rate by using the different features of the dataset. Some of the features being Sex, Port Of Embarcation, Age,etc.
#
# First let us understand the different types of features.

# %% [markdown]
# ## Types Of Features
#
# ### Categorical Features:
# A categorical variable is one that has two or more categories and each value in that feature can be categorised by them.For example, gender is a categorical variable having two categories (male and female). Now we cannot sort or give any ordering to such variables. They are also known as **Nominal Variables**.
#
# **Categorical Features in the dataset: Sex,Embarked.**
#
# ### Ordinal Features:
# An ordinal variable is similar to categorical values, but the difference between them is that we can have relative ordering or sorting between the values. For eg: If we have a feature like **Height** with values **Tall, Medium, Short**, then Height is a ordinal variable. Here we can have a relative sort in the variable.
#
# **Ordinal Features in the dataset: PClass**
#
# ### Continous Feature:
# A feature is said to be continous if it can take values between any two points or between the minimum or maximum values in the features column.
#
# **Continous Features in the dataset: Age**

# %% [markdown]
# ## Analysing the Features

# %% [markdown]
# ### Sex --> Categorical Feature

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax = plt.subplots(1,2, figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot(data=data, x='Sex',hue='Survived',ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# This looks interesting. The number of men on the ship is lot more than the number of women. Still the number of women saved is almost twice the number of males saved. The survival rates for a **women on the ship is around 75% while that for men in around 18-19%.**
#
# This looks to be a **very important** feature for modeling. But is it the best??   Lets check other features.

# %% [markdown]
# ## Pclass --> Ordinal Feature

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_e47bf_row0_col0, #T_e47bf_row1_col1, #T_e47bf_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_e47bf_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_e47bf_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_e47bf_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_e47bf_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_e47bf_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_e47bf_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_e47bf_row3_col0, #T_e47bf_row3_col1, #T_e47bf_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e47bf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_e47bf_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e47bf_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e47bf_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e47bf_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e47bf_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_e47bf_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_e47bf_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_e47bf_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e47bf_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_e47bf_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_e47bf_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_e47bf_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e47bf_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_e47bf_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_e47bf_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_e47bf_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_e47bf_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_e47bf_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_e47bf_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
round(data[data['Pclass']==1]['Survived'].value_counts()/len(data[data['Pclass']==1])*100,2)
# Out:
# 1    62.96
# 0    37.04
# Name: Survived, dtype: float64

# %%
round(data[data['Pclass']==2]['Survived'].value_counts()/len(data[data['Pclass']==2])*100,2)
# Out:
# 0    52.72
# 1    47.28
# Name: Survived, dtype: float64

# %%
round(data[data['Pclass']==3]['Survived'].value_counts()/len(data[data['Pclass']==3])*100,2)
# Out:
# 0    75.76
# 1    24.24
# Name: Survived, dtype: float64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot(x='Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dad')
plt.show()

# %% [markdown]
# People say **Money Can't Buy Everything**. But we can clearly see that Passenegers Of Pclass 1 were given a very high priority while rescue. Even though the the number of Passengers in Pclass 3 were a lot higher, still the number of survival from them is very low, somewhere around **25%**.
#
# For Pclass 1 %survived is around **63%** while for Pclass2 is around **48%**. So money and status matters. Such a materialistic world.
#
# Lets Dive in little bit more and check for other interesting observations. Lets check survival rate with **Sex and Pclass** Together.

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_3e2c2_row0_col0, #T_3e2c2_row0_col1, #T_3e2c2_row0_col3, #T_3e2c2_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_3e2c2_row0_col2, #T_3e2c2_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_3e2c2_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_3e2c2_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_3e2c2_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_3e2c2_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_3e2c2_row2_col1, #T_3e2c2_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_3e2c2_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_3e2c2_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_3e2c2_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_3e2c2_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_3e2c2_row4_col0, #T_3e2c2_row4_col1, #T_3e2c2_row4_col2, #T_3e2c2_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3e2c2">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_3e2c2_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_3e2c2_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_3e2c2_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_3e2c2_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e2c2_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_3e2c2_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_3e2c2_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_3e2c2_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_3e2c2_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_3e2c2_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_3e2c2_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_3e2c2_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_3e2c2_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_3e2c2_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_3e2c2_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_3e2c2_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_3e2c2_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_3e2c2_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_3e2c2_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_3e2c2_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_3e2c2_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_3e2c2_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_3e2c2_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_3e2c2_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_3e2c2_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_3e2c2_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_3e2c2_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_3e2c2_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_3e2c2_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_3e2c2_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_3e2c2_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_3e2c2_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.catplot(data=data,x='Pclass',y='Survived',hue='Sex',kind='point')
plt.show()

# %% [markdown]
# ### Age --> Continuos Feature

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
pd.crosstab([data.Age,data.Survived],data.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_6fcdf_row0_col0, #T_6fcdf_row0_col1, #T_6fcdf_row0_col2, #T_6fcdf_row0_col3, #T_6fcdf_row1_col0, #T_6fcdf_row1_col2, #T_6fcdf_row1_col3, #T_6fcdf_row2_col0, #T_6fcdf_row2_col1, #T_6fcdf_row2_col3, #T_6fcdf_row3_col0, #T_6fcdf_row3_col2, #T_6fcdf_row3_col3, #T_6fcdf_row4_col1, #T_6fcdf_row4_col2, #T_6fcdf_row4_col3, #T_6fcdf_row5_col0, #T_6fcdf_row5_col1, #T_6fcdf_row5_col3, #T_6fcdf_row6_col0, #T_6fcdf_row7_col1, #T_6fcdf_row8_col0, #T_6fcdf_row8_col2, #T_6fcdf_row8_col3, #T_6fcdf_row9_col0, #T_6fcdf_row9_col1, #T_6fcdf_row9_col2, #T_6fcdf_row9_col3, #T_6fcdf_row10_col0, #T_6fcdf_row11_col0, #T_6fcdf_row11_col1, #T_6fcdf_row11_col3, #T_6fcdf_row13_col0, #T_6fcdf_row14_col0, #T_6fcdf_row14_col1, #T_6fcdf_row14_col2, #T_6fcdf_row14_col3, #T_6fcdf_row15_col0, #T_6fcdf_row15_col2, #T_6fcdf_row15_col3, #T_6fcdf_row16_col0, #T_6fcdf_row16_col1, #T_6fcdf_row16_col3, #T_6fcdf_row17_col0, #T_6fcdf_row17_col2, #T_6fcdf_row17_col3, #T_6fcdf_row18_col0, #T_6fcdf_row18_col1, #T_6fcdf_row18_col3, #T_6fcdf_row19_col0, #T_6fcdf_row19_col2, #T_6fcdf_row19_col3, #T_6fcdf_row20_col0, #T_6fcdf_row20_col1, #T_6fcdf_row21_col0, #T_6fcdf_row21_col1, #T_6fcdf_row21_col3, #T_6fcdf_row22_col0, #T_6fcdf_row22_col1, #T_6fcdf_row22_col3, #T_6fcdf_row23_col0, #T_6fcdf_row23_col1, #T_6fcdf_row23_col3, #T_6fcdf_row24_col1, #T_6fcdf_row24_col2, #T_6fcdf_row24_col3, #T_6fcdf_row25_col0, #T_6fcdf_row25_col1, #T_6fcdf_row25_col2, #T_6fcdf_row25_col3, #T_6fcdf_row26_col0, #T_6fcdf_row26_col2, #T_6fcdf_row26_col3, #T_6fcdf_row27_col0, #T_6fcdf_row27_col1, #T_6fcdf_row27_col3, #T_6fcdf_row28_col2, #T_6fcdf_row28_col3, #T_6fcdf_row29_col0, #T_6fcdf_row29_col1, #T_6fcdf_row29_col2, #T_6fcdf_row29_col3, #T_6fcdf_row30_col0, #T_6fcdf_row30_col1, #T_6fcdf_row30_col2, #T_6fcdf_row30_col3, #T_6fcdf_row31_col1, #T_6fcdf_row32_col0, #T_6fcdf_row33_col1, #T_6fcdf_row34_col0, #T_6fcdf_row34_col1, #T_6fcdf_row35_col2, #T_6fcdf_row40_col0, #T_6fcdf_row40_col1, #T_6fcdf_row41_col0, #T_6fcdf_row41_col1, #T_6fcdf_row41_col3, #T_6fcdf_row42_col0, #T_6fcdf_row42_col1, #T_6fcdf_row42_col2, #T_6fcdf_row42_col3, #T_6fcdf_row45_col1, #T_6fcdf_row47_col0, #T_6fcdf_row48_col2, #T_6fcdf_row49_col0, #T_6fcdf_row49_col1, #T_6fcdf_row49_col2, #T_6fcdf_row49_col3, #T_6fcdf_row52_col0, #T_6fcdf_row52_col1, #T_6fcdf_row52_col2, #T_6fcdf_row52_col3, #T_6fcdf_row55_col0, #T_6fcdf_row56_col1, #T_6fcdf_row60_col2, #T_6fcdf_row61_col0, #T_6fcdf_row61_col1, #T_6fcdf_row61_col3, #T_6fcdf_row66_col0, #T_6fcdf_row66_col1, #T_6fcdf_row66_col3, #T_6fcdf_row69_col0, #T_6fcdf_row71_col0, #T_6fcdf_row71_col2, #T_6fcdf_row71_col3, #T_6fcdf_row72_col0, #T_6fcdf_row72_col2, #T_6fcdf_row72_col3, #T_6fcdf_row74_col2, #T_6fcdf_row75_col0, #T_6fcdf_row76_col2, #T_6fcdf_row77_col0, #T_6fcdf_row77_col1, #T_6fcdf_row77_col2, #T_6fcdf_row77_col3, #T_6fcdf_row78_col0, #T_6fcdf_row79_col2, #T_6fcdf_row81_col2, #T_6fcdf_row82_col0, #T_6fcdf_row82_col2, #T_6fcdf_row82_col3, #T_6fcdf_row84_col1, #T_6fcdf_row84_col2, #T_6fcdf_row84_col3, #T_6fcdf_row86_col1, #T_6fcdf_row86_col2, #T_6fcdf_row88_col1, #T_6fcdf_row88_col2, #T_6fcdf_row89_col1, #T_6fcdf_row90_col2, #T_6fcdf_row91_col0, #T_6fcdf_row91_col1, #T_6fcdf_row91_col3, #T_6fcdf_row92_col0, #T_6fcdf_row92_col1, #T_6fcdf_row93_col2, #T_6fcdf_row93_col3, #T_6fcdf_row95_col2, #T_6fcdf_row96_col0, #T_6fcdf_row97_col1, #T_6fcdf_row97_col2, #T_6fcdf_row97_col3, #T_6fcdf_row99_col1, #T_6fcdf_row99_col2, #T_6fcdf_row99_col3, #T_6fcdf_row100_col1, #T_6fcdf_row101_col2, #T_6fcdf_row102_col1, #T_6fcdf_row102_col2, #T_6fcdf_row102_col3, #T_6fcdf_row103_col2, #T_6fcdf_row103_col3, #T_6fcdf_row105_col1, #T_6fcdf_row105_col2, #T_6fcdf_row105_col3, #T_6fcdf_row106_col0, #T_6fcdf_row106_col3, #T_6fcdf_row107_col2, #T_6fcdf_row108_col1, #T_6fcdf_row108_col2, #T_6fcdf_row108_col3, #T_6fcdf_row109_col1, #T_6fcdf_row109_col2, #T_6fcdf_row110_col2, #T_6fcdf_row111_col2, #T_6fcdf_row113_col1, #T_6fcdf_row113_col2, #T_6fcdf_row113_col3, #T_6fcdf_row114_col2, #T_6fcdf_row114_col3, #T_6fcdf_row1 ...
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6fcdf_row1_col1, #T_6fcdf_row2_col2, #T_6fcdf_row4_col0, #T_6fcdf_row5_col2, #T_6fcdf_row6_col3, #T_6fcdf_row7_col0, #T_6fcdf_row10_col2, #T_6fcdf_row10_col3, #T_6fcdf_row12_col0, #T_6fcdf_row13_col1, #T_6fcdf_row13_col3, #T_6fcdf_row15_col1, #T_6fcdf_row16_col2, #T_6fcdf_row17_col1, #T_6fcdf_row18_col2, #T_6fcdf_row20_col3, #T_6fcdf_row21_col2, #T_6fcdf_row22_col2, #T_6fcdf_row24_col0, #T_6fcdf_row26_col1, #T_6fcdf_row28_col0, #T_6fcdf_row28_col1, #T_6fcdf_row31_col0, #T_6fcdf_row31_col3, #T_6fcdf_row33_col3, #T_6fcdf_row35_col3, #T_6fcdf_row36_col0, #T_6fcdf_row43_col0, #T_6fcdf_row44_col1, #T_6fcdf_row44_col2, #T_6fcdf_row44_col3, #T_6fcdf_row45_col0, #T_6fcdf_row48_col1, #T_6fcdf_row48_col3, #T_6fcdf_row53_col0, #T_6fcdf_row54_col2, #T_6fcdf_row54_col3, #T_6fcdf_row56_col3, #T_6fcdf_row57_col0, #T_6fcdf_row57_col2, #T_6fcdf_row61_col2, #T_6fcdf_row63_col0, #T_6fcdf_row64_col0, #T_6fcdf_row65_col2, #T_6fcdf_row66_col2, #T_6fcdf_row71_col1, #T_6fcdf_row72_col1, #T_6fcdf_row73_col0, #T_6fcdf_row73_col1, #T_6fcdf_row74_col3, #T_6fcdf_row76_col0, #T_6fcdf_row76_col3, #T_6fcdf_row79_col1, #T_6fcdf_row82_col1, #T_6fcdf_row83_col1, #T_6fcdf_row83_col2, #T_6fcdf_row83_col3, #T_6fcdf_row84_col0, #T_6fcdf_row85_col1, #T_6fcdf_row85_col3, #T_6fcdf_row86_col3, #T_6fcdf_row87_col0, #T_6fcdf_row88_col3, #T_6fcdf_row90_col3, #T_6fcdf_row91_col2, #T_6fcdf_row92_col3, #T_6fcdf_row93_col0, #T_6fcdf_row93_col1, #T_6fcdf_row94_col0, #T_6fcdf_row95_col3, #T_6fcdf_row96_col1, #T_6fcdf_row96_col3, #T_6fcdf_row97_col0, #T_6fcdf_row98_col0, #T_6fcdf_row98_col3, #T_6fcdf_row101_col3, #T_6fcdf_row102_col0, #T_6fcdf_row103_col1, #T_6fcdf_row104_col1, #T_6fcdf_row105_col0, #T_6fcdf_row106_col1, #T_6fcdf_row106_col2, #T_6fcdf_row107_col1, #T_6fcdf_row107_col3, #T_6fcdf_row108_col0, #T_6fcdf_row109_col3, #T_6fcdf_row110_col1, #T_6fcdf_row110_col3, #T_6fcdf_row111_col3, #T_6fcdf_row112_col0, #T_6fcdf_row112_col1, #T_6fcdf_row112_col3, #T_6fcdf_row114_col0, #T_6fcdf_row116_col0, #T_6fcdf_row117_col3, #T_6fcdf_row118_col1, #T_6fcdf_row119_col0, #T_6fcdf_row120_col1, #T_6fcdf_row127_col1, #T_6fcdf_row128_col0, #T_6fcdf_row128_col1, #T_6fcdf_row132_col0, #T_6fcdf_row132_col1, #T_6fcdf_row133_col0, #T_6fcdf_row136_

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot(data,x='Pclass',y='Age',hue='Survived',split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot(data,x='Sex',y='Age',hue='Survived',split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1]/set_yticks(range(0,110,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [70], in <cell line: 2>()
#       1 f,ax=plt.subplots(1,2,figsize=(18,8))
# ----> 2 sns.violinplot(data,x='Pclass',y='Age',hue='Survived',split=True,ax=ax[0])
#       3 ax[0].set_title('Pclass and Age vs Survived')
#       4 ax[0].set_yticks(range(0,110,10))
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:2400, in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2388 @_deprecate_positional_args
#    2389 def violinplot(
#    2390     *,
#    (...)
#    2397     ax=None, **kwargs,
#    2398 ):
# -> 2400     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2401                              bw, cut, scale, scale_hue, gridsize,
#    2402                              width, inner, split, dodge, orient, linewidth,
#    2403                              color, palette, saturation)
#    2405     if ax is None:
#    2406         ax = plt.gca()
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:522, in _ViolinPlotter.__init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     517 def __init__(self, x, y, hue, data, order, hue_order,
#     518              bw, cut, scale, scale_hue, gridsize,
#     519              width, inner, split, dodge, orient, linewidth,
#     520              color, palette, saturation):
# --> 522     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     523     self.establish_colors(color, palette, saturation)
#     524     self.estimate_densities(bw, cut, scale, scale_hue, gridsize)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:153, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151     if isinstance(var, str):
#     152         err = "Could not interpret input '{}'".format(var)
# --> 153         raise ValueError(err)
#     155 # Figure out the plotting orientation
#     156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#
# ValueError: Could not interpret input 'Age'
